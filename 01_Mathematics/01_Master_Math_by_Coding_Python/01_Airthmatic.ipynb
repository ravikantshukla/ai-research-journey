# %%
# Install GitHub CLI
# !pip install requests

# Configure git identity
# !git config --global user.email "ravikantshukla91@gmail.com"
# !git config --global user.name "Ravi kant Shukla"

print("✅ Git configured")
# Out:
# ...
# ✅ Git configured

# %%
# SETUP — Run this first always
from google.colab import drive, userdata
import os

drive.mount('/content/drive')

# Pull token safely from Secrets
GITHUB_TOKEN    = userdata.get('GITHUB_TOKEN')
GITHUB_USERNAME = "ravikantshukla"
REPO_NAME       = "ai-research-journey"

# Clone repo if not already cloned
repo_path = f"/content/{REPO_NAME}"
if not os.path.exists(repo_path):
    os.system(f"git clone https://{GITHUB_USERNAME}:{GITHUB_TOKEN}@github.com/{GITHUB_USERNAME}/{REPO_NAME}.git")
    print("✅ Repo cloned")
else:
    print("✅ Repo already exists")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# ✅ Repo already exists

# %%
import os

path = '/content/drive/MyDrive/AI_Research_Journey/01_Mathematics/'
folders = os.listdir(path)
print(folders)
# Out:
# ['01_Master_Math_by_Coding_Python', '02_Linear_Algebra', '03_Calculus', '04_Statistics_Probability', '05_Imperial_Coursera', 'Weekly_Reviews']

# %%
import os

# After you know exact folder name from above
folder = '/content/drive/MyDrive/AI_Research_Journey/01_Mathematics/01_Master_Math_by_Coding_Python/'
files = os.listdir(folder)
print(files)

# Should print:
# ['01_Airthmatic.ipynb']
# Out:
# ['01_Airthmatic.ipynb']
